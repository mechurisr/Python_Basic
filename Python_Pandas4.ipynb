# %%
import os
import sys
import pandas as pd

# %%
import sys
sys.version
# Out:
# '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]'

# %%
testCSV_path = 'C:\\Users\\acorn-519\\Desktop\\sampledata\\01_olive.csv'

olive_oil = pd.read_csv(testCSV_path)
olive_oil.head(10)
# Out:
#         Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0   1.North-Apulia       1     1      1075           75      226   7823
# 1   2.North-Apulia       1     1      1088           73      224   7709
# 2   3.North-Apulia       1     1       911           54      246   8113
# 3   4.North-Apulia       1     1       966           57      240   7952
# 4   5.North-Apulia       1     1      1051           67      259   7771
# 5   6.North-Apulia       1     1       911           49      268   7924
# 6   7.North-Apulia       1     1       922           66      264   7990
# 7   8.North-Apulia       1     1      1100           61      235   7728
# 8   9.North-Apulia       1     1      1082           60      239   7745
# 9  10.North-Apulia       1     1      1037           55      213   7944
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# ...

# %%
olive_oil = pd.read_csv(testCSV_path, names=["a","b","c","d"])
olive_oil.head(3)
# Out:
#                                                                       a  \
# NaN            region area palmitic palmitoleic stearic oleic  linoleic
# 1.North-Apulia 1      1    1075     75          226     7823        672
# 2.North-Apulia 1      1    1088     73          224     7709        781
#
#                                                                        b  \
# NaN            region area palmitic palmitoleic stearic oleic  linolenic
# 1.North-Apulia 1      1    1075     75          226     7823          36
# 2.North-Apulia 1      1    1088     73          224     7709          31
#
#                                                                        c  \
# NaN            region area palmitic palmitoleic stearic oleic  arachidic
# 1.North-Apulia 1      1    1075     75          226     7823          60
# 2.North-Apulia 1      1    1088     73          224     7709          61
#
#                                                                         d
# ...

# %%
olive_oil = pd.read_csv(testCSV_path, skiprows = 1)
olive_oil.head(3)
# Out:
#    1.North-Apulia  1  1.1  1075  75  226  7823  672  36  60  29
# 0  2.North-Apulia  1    1  1088  73  224  7709  781  31  61  29
# 1  3.North-Apulia  1    1   911  54  246  8113  549  31  63  29
# 2  4.North-Apulia  1    1   966  57  240  7952  619  50  78  35

# %%
olive_oil = pd.read_csv(testCSV_path, names=["a","b","c","d"])
olive_oil.head(3)
# Out:
#                                                                       a  \
# NaN            region area palmitic palmitoleic stearic oleic  linoleic
# 1.North-Apulia 1      1    1075     75          226     7823        672
# 2.North-Apulia 1      1    1088     73          224     7709        781
#
#                                                                        b  \
# NaN            region area palmitic palmitoleic stearic oleic  linolenic
# 1.North-Apulia 1      1    1075     75          226     7823          36
# 2.North-Apulia 1      1    1088     73          224     7709          31
#
#                                                                        c  \
# NaN            region area palmitic palmitoleic stearic oleic  arachidic
# 1.North-Apulia 1      1    1075     75          226     7823          60
# 2.North-Apulia 1      1    1088     73          224     7709          61
#
#                                                                         d
# ...

# %%
olive_oil = pd.read_csv(testCSV_path)
olive_oil.head(3)
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29

# %%
olive_oil.rename(columns = {'Unnamed: 0' : "id_area"}, inplace = True)
olive_oil.head(3)
# Out:
#           id_area  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29

# %%
olive_oil.rename(columns = {olive_oil.columns[0] : "id_area"}, inplace = True)
olive_oil.head(3)
# Out:
#           id_area  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29

# %%
olive_oil["id_area"].unique()
# Out:
# array(['1.North-Apulia', '2.North-Apulia', '3.North-Apulia',
#        '4.North-Apulia', '5.North-Apulia', '6.North-Apulia',
#        '7.North-Apulia', '8.North-Apulia', '9.North-Apulia',
#        '10.North-Apulia', '11.North-Apulia', '12.North-Apulia',
#        '13.North-Apulia', '14.North-Apulia', '15.North-Apulia',
#        '16.North-Apulia', '17.North-Apulia', '18.North-Apulia',
#        '19.North-Apulia', '20.North-Apulia', '21.North-Apulia',
#        '22.North-Apulia', '23.North-Apulia', '24.North-Apulia',
#        '25.North-Apulia', '26.Calabria', '27.Calabria', '28.Calabria',
#        '29.Calabria', '30.Calabria', '31.Calabria', '32.Calabria',
#        '33.Calabria', '34.Calabria', '35.Calabria', '36.Calabria',
#        '37.Calabria', '38.Calabria', '39.Calabria', '40.Calabria',
#        '41.Calabria', '42.Calabria', '43.Calabria', '44.Calabria',
#        '45.Calabria', '46.Calabria', '47.Calabria', '48.Calabria',
# ...

# %%
len(olive_oil["id_area"].unique())
# Out:
# 572

# %%
len(olive_oil)
# Out:
# 572

# %%
olive_oil.shape[0]
# Out:
# 572

# %%
olive_oil["id_area"][0]
# Out:
# '1.North-Apulia'

# %%
str(int('1.North-Apulia'.split(".")[0])-1)
# Out:
# '0'

# %%
str(int('1.North-Apulia'.split(".")[0])-1)+"_"+'1.North-Apulia'.split(".")[1]
# Out:
# '0_North-Apulia'

# %%
str(int('2.North-Apulia'.split(".")[0])-1)+"_"+'2.North-Apulia'.split(".")[1]

# %%
str(int(x.split(".")[0])-1)+"_"+x.split(".")[1]

# %%
olive_oil["id_area"]=olive_oil["id_area"].apply(lambda x:str(int(x.split(".")[0])-1)+"_"+x.split(".")[1])
olive_oil.head(5)
# Out:
#           id_area  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  0_North-Apulia       1     1      1075           75      226   7823
# 1  1_North-Apulia       1     1      1088           73      224   7709
# 2  2_North-Apulia       1     1       911           54      246   8113
# 3  3_North-Apulia       1     1       966           57      240   7952
# 4  4_North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
olive_oil["palmitoleic"] = olive_oil["palmitoleic"].apply(lambda x : x/100)
olive_oil.head(5)
# Out:
#           id_area  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  0_North-Apulia       1     1      1075         0.75      226   7823
# 1  1_North-Apulia       1     1      1088         0.73      224   7709
# 2  2_North-Apulia       1     1       911         0.54      246   8113
# 3  3_North-Apulia       1     1       966         0.57      240   7952
# 4  4_North-Apulia       1     1      1051         0.67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
olive_oil.to_csv("olive2.csv")

# %%
comma_path = "C:\\Users\\acorn-519\\Desktop\\sampledata\\02_surveys.csv"
at_path = "C:\\Users\\acorn-519\\Desktop\\sampledata\\03_surveys_withAt.csv"

data_comma = pd.read_csv(comma_path, sep=",")
data_comma
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
data_at = pd.read_csv(at_path, sep="@")
data_at
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
import sys
import os
import glob

# %%
many_file_path = "C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\*.csv"
many_file_path
# Out:
# 'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\*.csv'

# %% [markdown]
# glob.glob(many_file_path)

# %%
glob.glob(many_file_path)
# Out:
# ['C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1763.csv',
#  'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1764.csv',
#  'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1765.csv',
#  'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1766.csv',
#  'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1767.csv',
#  'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1768.csv',
#  'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1769.csv',
#  'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1770.csv',
#  'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1771.csv',
#  'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1772.csv']

# %%
glob.glob(many_file_path)[0]
# Out:
# 'C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\1763.csv'

# %%
os.path.basename(glob.glob(many_file_path)[0]).split(".")[0]
# Out:
# '1763'

# %%
many_file_path = "C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\*.csv"
file_path_list = glob.glob(many_file_path)

for i in range(0, len(file_path_list)):
    temp = os.path.basename(file_path_list[i])
    temp = os.path.splitext(temp)[0]
    
    #data_1763 = pd.read_csv(~~~~.1763.csv)
    vars()["data_" + str(temp)] = pd.read_csv(file_path_list[i])

# %%
data_1772.head()
# Out:
#    ITE00100554  17720101  TMAX  51  Unnamed: 4 Unnamed: 5  E  Unnamed: 7
# 0  ITE00100554  17720101  TMIN  31         NaN        NaN  E         NaN
# 1  ITE00100554  17720102  TMAX  48         NaN        NaN  E         NaN
# 2  ITE00100554  17720102  TMIN  18         NaN        NaN  E         NaN
# 3  ITE00100554  17720103  TMAX  38         NaN        NaN  E         NaN
# 4  ITE00100554  17720103  TMIN  18         NaN        NaN  E         NaN

# %%
many_file_path = "C:\\Users\\acorn-519\\Desktop\\sampledata\\06_manyfile\\*.csv"
file_path_list = glob.glob(many_file_path)

data_tot = pd.DataFrame()
for i in range(0, len(file_path_list)):
    data_tot = data_tot.append(pd.read_csv(file_path_list[i], header = None), ignore_index = True)

# %%
data_tot.shape
# Out:
# (7306, 8)

# %%
data_1772.shape
# Out:
# (731, 8)

# %%
excel_path = "C:\\Users\\acorn-519\\Desktop\\sampledata\\07_surveys_excelformat.xls"
excel_data = pd.read_excel(excel_path, sheet_name="Sheet1")
excel_data.head(3)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN

# %%
excel_data = excel_data.fillna(0)
excel_data.head(3)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     0.0
# 1     0.0
# 2     0.0

# %%
excel_out_path1 = "test_excel_old.xls"
excel_out_path2 = "test_excel_new.xlsx"
excel_data.to_excel(excel_out_path1)
excel_data.to_excel(excel_out_path2)

# %%
big_file_path = "C:\\Users\\acorn-519\\Desktop\\sampledata\\star2002-1.csv"

chunker = pd.read_csv(big_file_path, chunksize = 1000)
tot = pd.concat([x for x in chunker], ignore_index = True)
tot.shape
# Out:
# (4999999, 16)

# %%
pd.read_csv(big_file_path).head()
# Out:
#    1   1613423   807   20011015.2226039991   1613424   4518   0   0.1   654  \
# 0  1   1613423   808          2.001102e+07   1613424    886   0     0    61
# 1  1   1613423   809          2.001102e+07   1613424    638   0     0     7
# 2  4   1613423   810          2.001102e+07   1613424   4259   0     0  1024
# 3  5   1613423   811          2.001102e+07   1613424   3673   1     0   592
# 4  3   1613423   812          2.001102e+07   1613424   4707   0     0   655
#
#     1395   20011204.1149509996   10.955403   2288071   -0.28820264  \
# 0    371          2.001120e+07   23.326479   2288071     -0.247330
# 1    121          2.001120e+07    2.444299   2288071     -0.390961
# 2   1302          2.001120e+07    9.521868   2288071     -0.290154
# 3   1246          2.001120e+07   13.560424   2288071     -0.257418
# 4   1529          2.001120e+07   47.679569   2288071     -0.221794
#
#     0.40731233   10.559091
# 0     0.455916   57.810596
# 1     0.589534  167.757140
# ...
