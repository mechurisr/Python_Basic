# %% [markdown]
# ### Telecom_Churn Data Part2

# %% [markdown]
# * 필요한 라이브러리 불러오기 : numpy, pandas, matplotlib, seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# * telecom_churn.csv 파일 읽어오기

# %%
df = pd.read_csv("telecom_churn.csv")
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# * Total day minutes / Total intl calls에 대한 히스토 그램을 그리시오 : 1판에 2개를 한 번에 그리세요!!

# %%
features = ['Total day minutes', 'Total intl calls']
df[features].hist(figsize = (10, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000270A3F96048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000270A46C07C8>]],
#       dtype=object)

# %% [markdown]
# * 위의 그래프에 대한 밀도함수로 그래프 그리기

# %%
df[features].plot(kind = density)

# %% [markdown]
# * toal intl calls 에 관련된 히스토그램과 밀도함수를 동시에 나타내시오.

# %%
sns.distplot(df['Total intl calls'])

# %% [markdown]
# * Total intl calls에 대한 박스플롯을 생성하시오!!

# %% [markdown]
# * Total intl calls 에 대한 boxplot와 violinplot 를 모두 생성하시오!!

# %% [markdown]
# * feature에 관련된 기본적인 통계 정보를 확인하시오!!!

# %%
# Out:
#        Total day minutes  Total intl calls
# count        3333.000000       3333.000000
# mean          179.775098          4.479448
# std            54.467389          2.461214
# min             0.000000          0.000000
# 25%           143.700000          3.000000
# 50%           179.400000          4.000000
# 75%           216.400000          6.000000
# max           350.800000         20.000000

# %% [markdown]
# * churn의 컬럼의 값이 종류별로 몇 가지가 있는지 확인!

# %%
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
# Out:
# 2850

# %%
# Out:
# 483

# %% [markdown]
# * 위의 count관련된 부분에 대한 그래프를 그리시오..대상은 churn/customer service calls

# %% [markdown]
# * 수치 데이터 컬럼들을 리스트로 만들고, 이들에 대한 것들을 바탕으로 상관계수/히트맵을 완성하시오!!

# %%
# Out:
#                        Total night calls  Total eve charge  \
# Total night calls               1.000000          0.007596
# Total eve charge                0.007596          1.000000
# Total night charge              0.011188         -0.012601
# Number vmail messages           0.007123          0.017578
# Total eve calls                 0.007710         -0.011423
# Total intl charge              -0.013630         -0.011074
# Total eve minutes               0.007586          1.000000
# Total day calls                -0.019557         -0.021449
# Total intl calls                0.000305          0.002541
# Total night minutes             0.011204         -0.012592
# Total intl minutes             -0.013605         -0.011043
# Total day charge                0.022972          0.007036
# Account length                 -0.013176         -0.006745
# Total day minutes               0.022972          0.007029
#
#                        Total night charge  Number vmail messages  \
# Total night calls                0.011188               0.007123
# Total eve charge                -0.012601               0.017578
# Total night charge               1.000000               0.007663
# Number vmail messages            0.007663               1.000000
# Total eve calls                 -0.002056              -0.005864
# Total intl charge               -0.015186               0.002884
# Total eve minutes               -0.012593               0.017562
# Total day calls                  0.022927              -0.009548
# Total intl calls                -0.012329               0.013957
# Total night minutes              0.999999               0.007681
# Total intl minutes              -0.015214               0.002856
# Total day charge                 0.004301               0.000776
# Account length                  -0.008960              -0.004628
# Total day minutes                0.004300               0.000778
#
#                        Total eve calls  Total intl charge  Total eve minutes  \
# Total night calls             0.007710          -0.013630           0.007586
# Total eve charge             -0.011423          -0.011074           1.000000
# Total night charge           -0.002056          -0.015186          -0.012593
# Number vmail messages        -0.005864           0.002884           0.017562
# Total eve calls               1.000000           0.008674          -0.011430
# Total intl charge             0.008674           1.000000          -0.011067
# Total eve minutes            -0.011430          -0.011067           1.000000
# Total day calls               0.006462           0.021666          -0.021451
# Total intl calls              0.017434           0.032372           0.002541
# Total night minutes          -0.002093          -0.015180          -0.012584
# Total intl minutes            0.008703           0.999993          -0.011035
# Total day charge              0.015769          -0.010094           0.007050
# Account length                0.019260           0.009546          -0.006757
# Total day minutes             0.015769          -0.010092           0.007043
#
#                        Total day calls  Total intl calls  Total night minutes  \
# Total night calls            -0.019557          0.000305             0.011204
# Total eve charge             -0.021449          0.002541            -0.012592
# Total night charge            0.022927         -0.012329             0.999999
# Number vmail messages        -0.009548          0.013957             0.007681
# Total eve calls               0.006462          0.017434            -0.002093
# Total intl charge             0.021666          0.032372            -0.015180
# Total eve minutes            -0.021451          0.002541            -0.012584
# Total day calls               1.000000          0.004574             0.022938
# Total intl calls              0.004574          1.000000            -0.012353
# Total night minutes           0.022938         -0.012353             1.000000
# Total intl minutes            0.021565          0.032304            -0.015207
# Total day charge              0.006753          0.008032             0.004324
# Account length                0.038470          0.020661            -0.008955
# Total day minutes             0.006750          0.008033             0.004323
#
#                        Total intl minutes  Total day charge  Account length  \
# Total night calls               -0.013605          0.022972       -0.013176
# Total eve charge                -0.011043          0.007036       -0.006745
# Total night charge              -0.015214          0.004301       -0.008960
# Number vmail messages            0.002856          0.000776       -0.004628
# Total eve calls                  0.008703          0.015769        0.019260
# Total intl charge                0.999993         -0.010094        0.009546
# Total eve minutes               -0.011035          0.007050       -0.006757
# Total day calls                  0.021565          0.006753        0.038470
# Total intl calls                 0.032304          0.008032        0.020661
# Total night minutes             -0.015207          0.004324       -0.008955
# Total intl minutes               1.000000         -0.010157        0.009514
# Total day charge                -0.010157          1.000000        0.006214
# Account length                   0.009514          0.006214        1.000000
# Total day minutes               -0.010155          1.000000        0.006216
#
#                        Total day minutes
# Total night calls               0.022972
# Total eve charge                0.007029
# Total night charge              0.004300
# Number vmail messages           0.000778
# Total eve calls                 0.015769
# Total intl charge              -0.010092
# Total eve minutes               0.007043
# Total day calls                 0.006750
# Total intl calls                0.008033
# Total night minutes             0.004323
# Total intl minutes             -0.010155
# Total day charge                1.000000
# Account length                  0.006216
# Total day minutes               1.000000

# %%
# 전체에서 수치 컬럼이 아닌 것들을 선정해서 제거하기!!!!


# Calculate and plot

# %% [markdown]
# * numerical 에서 기존의 모든 수치 중에서 charge 관련된 부분들을 모두 제거할 것!!!

# %% [markdown]
# * Total day minutes / Total night minutes 간의 스캐터 그래프를 그리시오!!

# %% [markdown]
# * 위의 그래프를 스캐터로 그리고, 그 옆에 밀도 함수 그래프가지 같이 나타내시오!!!

# %% [markdown]
# * 위의 그래프에 대한 색을 변경해보자!!

# %% [markdown]
# * 앞에서 조정한 모든 수치변수들의 모든 값들에 대한 pairplot를 그려보자!!!!

# %% [markdown]
# * 위의 스캐터 그래프이지만, 카테고리 변수의 값에 대한 것들로 구별하면서 보고 싶을때..

# %% [markdown]
# * 기존의 numerical 컬럼에다사 customer service calls를 추가를 하고, 해당하는 numerical 변수와 churn의 값에 대한 boxplot를 그려보시오!

# %% [markdown]
# * 서브플롯을 이용하여서 2개의 그래프를 그리는데, 1개는 boxplot/ 1개는 violinplot를 그리시오. 가로 : Churn, 세로 : Total day minutes

# %% [markdown]
# * 아래의 그래프와 같이 나타내시오!!!

# %% [markdown]
# * Customer service calls에 대한 값을 countplot을 그리는데, churn의 값을 기준으로 모두 보고싶을때..

# %% [markdown]
# * 아래 그림과 같이 churn의 값에 따른 countplot를 생성하시오!!!

# %% [markdown]
# * Staes 별로 Churn의 분포를 보고 싶어서 아래와 같이 crosstab을 이용해서 생성하시오!!

# %%
# Out:
# State  AK  AL  AR  AZ  CA  CO  CT  DC  DE  FL  ...  SD  TN  TX  UT  VA  VT  \
# Churn                                          ...
# False  49  72  44  60  25  57  62  49  52  55  ...  52  48  54  62  72  65
# True    3   8  11   4   9   9  12   5   9   8  ...   8   5  18  10   5   8
#
# State  WA  WI  WV  WY
# Churn
# False  52  71  96  68
# True   14   7  10   9
#
# [2 rows x 51 columns]

# %% [markdown]
# * 위의 결과를 groupby를 이용해서 하시면서, 평균에 대한 값들로 정리를 하고, 평균값이 높은 순서대로 정리하시오!!!

# %%
# Out:
# State        NJ        CA    TX        MD        SC        MI        MS  \
# mean   0.264706  0.264706  0.25  0.242857  0.233333  0.219178  0.215385
#
# State        NV        WA        ME  ...        RI        WI        IL  \
# mean   0.212121  0.212121  0.209677  ...  0.092308  0.089744  0.086207
#
# State        NE        LA        IA        VA      AZ        AK        HI
# mean   0.081967  0.078431  0.068182  0.064935  0.0625  0.057692  0.056604
#
# [1 rows x 51 columns]
