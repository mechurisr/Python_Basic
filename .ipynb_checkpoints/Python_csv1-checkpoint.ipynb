# %%
import pandas as pd
import json

# %%
#01) json 만들기
# """ {키 : 값} """
json_data1 = """{
    "color" : "red",
    "value" : "#100"
}"""

result = json.loads(json_data1)
print(result)
# Out:
# {'color': 'red', 'value': '#100'}

# %%
result["color"]
# Out:
# 'red'

# %%
result["value"]
# Out:
# '#100'

# %%
result.keys()
# Out:
# dict_keys(['color', 'value'])

# %%
# 02) json data 2
json_data2 = """{
    "id": "0001",
    "type": "donut",
    "name": "Cake",
    "ppu": 0.55,
    "batters":{
            "batter": [
                            { "id": "1001", "type": "Regular" },
                            { "id": "1002", "type": "Chocolate" },
                            { "id": "1003", "type": "Blueberry" },
                            { "id": "1004", "type": "Devil's Food" }
                            ]
                        },
    "topping":
        [
            { "id": "5001", "type": "None" },
            { "id": "5002", "type": "Glazed" },
            { "id": "5005", "type": "Sugar" },
            { "id": "5007", "type": "Powdered Sugar" },
            { "id": "5006", "type": "Chocolate with Sprinkles" },
            { "id": "5003", "type": "Chocolate" },
            { "id": "5004", "type": "Maple" }
]
}"""
result = json.loads(json_data2)
print(result)
# Out:
# {'id': '0001', 'type': 'donut', 'name': 'Cake', 'ppu': 0.55, 'batters': {'batter': [{'id': '1001', 'type': 'Regular'}, {'id': '1002', 'type': 'Chocolate'}, {'id': '1003', 'type': 'Blueberry'}, {'id': '1004', 'type': "Devil's Food"}]}, 'topping': [{'id': '5001', 'type': 'None'}, {'id': '5002', 'type': 'Glazed'}, {'id': '5005', 'type': 'Sugar'}, {'id': '5007', 'type': 'Powdered Sugar'}, {'id': '5006', 'type': 'Chocolate with Sprinkles'}, {'id': '5003', 'type': 'Chocolate'}, {'id': '5004', 'type': 'Maple'}]}

# %%
result["topping"]
# Out:
# [{'id': '5001', 'type': 'None'},
#  {'id': '5002', 'type': 'Glazed'},
#  {'id': '5005', 'type': 'Sugar'},
#  {'id': '5007', 'type': 'Powdered Sugar'},
#  {'id': '5006', 'type': 'Chocolate with Sprinkles'},
#  {'id': '5003', 'type': 'Chocolate'},
#  {'id': '5004', 'type': 'Maple'}]

# %%
result["topping"][2]["type"]
# Out:
# 'Sugar'

# %%
#batter 2번째 값을 출력 / 2번째 topping의 데이터를 출력

# %%
result["batters"]["batter"][1]["id"]
# Out:
# '1002'

# %%
result["topping"][1]
# Out:
# {'id': '5002', 'type': 'Glazed'}

# %%
import pandas as pd
import urllib.request
import json

# %%
movieIdListURL = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json?key=80b1793712960b5dfe1c3386942f37d9"
movieIdListURL
# Out:
# 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json?key=80b1793712960b5dfe1c3386942f37d9'

# %%
movieIdPage = urllib.request.urlopen(movieIdListURL)
movieIdData = json.loads(movieIdPage.read().decode('utf8'), encoding="utf8")
movieIdData
# Out:
# {'movieListResult': {'totCnt': 76570,
#   'source': '영화진흥위원회',
#   'movieList': [{'movieCd': '20191242',
#     'movieNm': '대전 블루스',
#     'movieNmEn': 'Last Blues, Last Dance',
#     'prdtYear': '2019',
#     'openDt': '20200423',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '한국',
#     'genreAlt': '드라마',
#     'repNationNm': '한국',
#     'repGenreNm': '드라마',
#     'directors': [{'peopleNm': '박철웅'}],
#     'companys': [{'companyCd': '2019961', 'companyNm': '스토리텔러'},
#      {'companyCd': '20060201', 'companyNm': '알리스필름'},
#      {'companyCd': '20203662', 'companyNm': '붐필름'},
#      {'companyCd': '20203663', 'companyNm': '송영철 공작소'}]},
#    {'movieCd': '20201785',
#     'movieNm': '태백권',
#     'movieNmEn': 'The Therapist: Fist of Tae-baek',
#     'prdtYear': '2020',
#     'openDt': '',
#     'typeNm': '장편',
#     'prdtStatNm': '',
#     'nationAlt': '한국',
#     'genreAlt': '코미디,가족,액션',
#     'repNationNm': '한국',
#     'repGenreNm': '코미디',
# ...

# %%
movieIdData["movieListResult"]["totCnt"]
# Out:
# 76570

# %%
movieIdData = json.loads(~~~~, encoding = "utf8")

movieIdData = json.loads(movieIdPage.read().decode('utf8'))

#movieIdPage.read().decode("utf8")
# Out:
#   File "<ipython-input-21-f5f21cdb6ab6>", line 1
#     movieIdData = json.loads(~~~~, encoding = "utf8")
#                                  ^
# SyntaxError: invalid syntax

# %%
movieIdData = json.loads(movieIdPage.read().decode('utf8'),encoding="utf8")
movieIdData
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-22-594377c49be8> in <module>
# ----> 1 movieIdData = json.loads(movieIdPage.read().decode('utf8'),encoding="utf8")
#       2 movieIdData
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...

# %%
movieIdData["movieListResult"]
# Out:
# {'totCnt': 76570,
#  'source': '영화진흥위원회',
#  'movieList': [{'movieCd': '20191242',
#    'movieNm': '대전 블루스',
#    'movieNmEn': 'Last Blues, Last Dance',
#    'prdtYear': '2019',
#    'openDt': '20200423',
#    'typeNm': '장편',
#    'prdtStatNm': '개봉',
#    'nationAlt': '한국',
#    'genreAlt': '드라마',
#    'repNationNm': '한국',
#    'repGenreNm': '드라마',
#    'directors': [{'peopleNm': '박철웅'}],
#    'companys': [{'companyCd': '2019961', 'companyNm': '스토리텔러'},
#     {'companyCd': '20060201', 'companyNm': '알리스필름'},
#     {'companyCd': '20203662', 'companyNm': '붐필름'},
#     {'companyCd': '20203663', 'companyNm': '송영철 공작소'}]},
#   {'movieCd': '20201785',
#    'movieNm': '태백권',
#    'movieNmEn': 'The Therapist: Fist of Tae-baek',
#    'prdtYear': '2020',
#    'openDt': '',
#    'typeNm': '장편',
#    'prdtStatNm': '',
#    'nationAlt': '한국',
#    'genreAlt': '코미디,가족,액션',
#    'repNationNm': '한국',
#    'repGenreNm': '코미디',
#    'directors': [{'peopleNm': '최상훈'}],
#    'companys': []},
# ...

# %%
movieIdPage = urllib.request.urlopen(movieIdListURL)
movieIdData = json.loads(movieIdPage.read().decode('utf8'),encoding="utf8")
movieIdData
# Out:
# {'movieListResult': {'totCnt': 76570,
#   'source': '영화진흥위원회',
#   'movieList': [{'movieCd': '20191242',
#     'movieNm': '대전 블루스',
#     'movieNmEn': 'Last Blues, Last Dance',
#     'prdtYear': '2019',
#     'openDt': '20200423',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '한국',
#     'genreAlt': '드라마',
#     'repNationNm': '한국',
#     'repGenreNm': '드라마',
#     'directors': [{'peopleNm': '박철웅'}],
#     'companys': [{'companyCd': '2019961', 'companyNm': '스토리텔러'},
#      {'companyCd': '20060201', 'companyNm': '알리스필름'},
#      {'companyCd': '20203662', 'companyNm': '붐필름'},
#      {'companyCd': '20203663', 'companyNm': '송영철 공작소'}]},
#    {'movieCd': '20201785',
#     'movieNm': '태백권',
#     'movieNmEn': 'The Therapist: Fist of Tae-baek',
#     'prdtYear': '2020',
#     'openDt': '',
#     'typeNm': '장편',
#     'prdtStatNm': '',
#     'nationAlt': '한국',
#     'genreAlt': '코미디,가족,액션',
#     'repNationNm': '한국',
#     'repGenreNm': '코미디',
# ...

# %%
movieIdData["movieListResult"]["movieList"][0]
# Out:
# {'movieCd': '20191242',
#  'movieNm': '대전 블루스',
#  'movieNmEn': 'Last Blues, Last Dance',
#  'prdtYear': '2019',
#  'openDt': '20200423',
#  'typeNm': '장편',
#  'prdtStatNm': '개봉',
#  'nationAlt': '한국',
#  'genreAlt': '드라마',
#  'repNationNm': '한국',
#  'repGenreNm': '드라마',
#  'directors': [{'peopleNm': '박철웅'}],
#  'companys': [{'companyCd': '2019961', 'companyNm': '스토리텔러'},
#   {'companyCd': '20060201', 'companyNm': '알리스필름'},
#   {'companyCd': '20203662', 'companyNm': '붐필름'},
#   {'companyCd': '20203663', 'companyNm': '송영철 공작소'}]}

# %%
#Q1) 처음 영화에 대한 movieCD값을 출력하세요.
#02) 처음 영화의 영화 이름/영문이름을 출력하세요.
#03) 처음 영화의 개봉일을 출력하세요.
#04) 처음 영화에 대한 1번 감독에 대한 정보를 점근을 하고, 그 감독의 이름을 출력하세요

# %%
movieIdData["movieListResult"]["movieList"][0]["movieCd"]
# Out:
# '20200304'

# %%
movieIdData["movieListResult"]["movieList"][0]["movieNm"]
# Out:
# '테우리'

# %%
movieIdData["movieListResult"]["movieList"][0]["movieNmEn"]
# Out:
# 'Teuri'

# %%
movieIdData["movieListResult"]["movieList"][0]["openDt"]
# Out:
# '20200709'

# %%
movieIdData["movieListResult"]["movieList"][0]["directors"][0]["peopleNm"]
# Out:
# '박철웅'

# %%
#모든 정보를 담을 DF
movieIDDF = pd.DataFrame()

#1개 영화 정보들에 대해서 처리할 DF
movieIDDF_temp = pd.DataFrame()
movieIDDF_temp = movieIDDF_temp.append(
    {"movieCd":"",
     "movieNm" : "",
     "movieNmEn" : "",
     "openDt" : "",
     "directorpeopleNm" : ""},
    ignore_index = True)

temp_movcd_idx = movieIDDF_temp.columns.get_loc("movieCd")
temp_movNm_idx = movieIDDF_temp.columns.get_loc("movieNm")
temp_movNmE_idx = movieIDDF_temp.columns.get_loc("movieNmEn")
temp_movdt_idx = movieIDDF_temp.columns.get_loc("openDt")
temp_movdir_idx = movieIDDF_temp.columns.get_loc("directorpeopleNm")

num = len(movieIdData["movieListResult"]["movieList"])
for i in range(0, num):
    #영화 코드
    movieIDDF_temp.iat[0, temp_movcd_idx]=movieIdData["movieListResult"]["movieList"][i]["movieCd"]
    movieIDDF_temp.iat[0, temp_movNm_idx]=movieIdData["movieListResult"]["movieList"][i]["movieNm"]
    movieIDDF_temp.iat[0, temp_movNmE_idx]=movieIdData["movieListResult"]["movieList"][i]["movieNmEn"]
    movieIDDF_temp.iat[0, temp_movdt_idx]=movieIdData["movieListResult"]["movieList"][i]["openDt"]
    
    
    #print(str(i)+"_번째 영화 코드: ", movieIdData["movieListResult"]["movieList"][i]["directors"]=[])
    #감독에 대한 정보가 뭐라도 들어있는 경우....
    if movieIdData["movieListResult"]["movieList"][i]["directors"] !=[]:
        #print(str(i) + "감독이름:", movieIdData[",movieLis0tResult"])
        movieIDDF_temp.iat[0,temp_movdir_idx]=movieIdData["movieListResult"]["movieList"][i]["directors"][0]["peopleNm"]
    else:
            pass
        
    

    
    # 1. movieIDDF_temp에 i번째 영화의 정보들을 담기....(코드, 이름, 영문, 개봉일, 감독)
    # 2. movieIDDF_temp에 있는 i번째 영화에 대한 정보를 movieIDDF에 추가
    # ---------> append
    movieIDDF=movieIDDF.append(movieIDDF_temp, ignore_index=True)
    # 3. movieIDDF_temp에 담겨져 있는 정보들을 초기화하는 부분
    movieIDDF_temp.iat[0, temp_movcd_idx] = ""
    movieIDDF_temp.iat[0, temp_movNm_idx] = ""
    movieIDDF_temp.iat[0, temp_movNmE_idx] = ""
    movieIDDF_temp.iat[0, temp_movdt_idx] = ""
    movieIDDF_temp.iat[0, temp_movdir_idx] = ""

# %%
movieIDDF_temp.columns.get_loc("movieCd")
# Out:
# 1

# %%
movieIdData["movieListResult"]["movieList"][5]["directors"]=[]

# %%
movieIDDF["openDt"][0]
# Out:
# '19720513'

# %%
movieIDDF["openDt"][0][:4]--->x[:4]
# Out:
#   File "<ipython-input-79-836ee51ac164>", line 1
#     movieIDDF["openDt"][0][:4]--->x[:4]
#                                  ^
# SyntaxError: invalid syntax

# %%
movieIDDF["openDt"][0][4:6]--->x[4:6]

# %%
movieIDDF["openDt"][0][6:]--->x[6:]

# %%
movieIDDF["year"]=movieIDDF["openDt"].apply(lambda x: str(x)[:4]) 
movieIDDF["month"]=movieIDDF["openDt"].apply(lambda x: str(x)[4:6])
movieIDDF["day"]=movieIDDF["openDt"].apply(lambda x: str(x)[6:])
movieIDDF.head(10)
# Out:
#   directorpeopleNm   movieCd         movieNm                        movieNmEn  \
# 0              박철웅  20191242          대전 블루스           Last Blues, Last Dance
# 1              최상훈  20201785             태백권  The Therapist: Fist of Tae-baek
# 2            켄 마리노  20200083         해피 디 데이                         Dog Days
# 3          마이클 폴리쉬  20200912       포스 오브 네이쳐                  Force of Nature
# 4                   20200802           킬 스위치                      Kill Switch
# 5        표도르 본다르추크  20208617       인베이젼 2020                         Invasion
# 6              조정래  20196201             소리꾼                       The Singer
# 7         예고르 바라노프  20200774  블랙아웃 : 인베이젼 어스                         Avanpost
# 8              연상호  20200846       부산행:익스텐디드
# 9         안드레 외브레달  20201385   모탈: 레전드 오브 토르                           MORTAL
#
#      openDt  year month day
# 0  20200423  2020    04  23
# 1
# 2  20200701  2020    07  01
# 3  20200701  2020    07  01
# ...

# %%
movieIDDF = movieIDDF.sort_values(by="openDt")
movieIDDF.head(10)
# Out:
#      openDt  year month day         movieNm                        movieNmEn  \
# 1                                       태백권  The Therapist: Fist of Tae-baek
# 7                            블랙아웃 : 인베이젼 어스                         Avanpost
# 0  20200423  2020    04  23          대전 블루스           Last Blues, Last Dance
# 2  20200701  2020    07  01         해피 디 데이                         Dog Days
# 3  20200701  2020    07  01       포스 오브 네이쳐                  Force of Nature
# 4  20200701  2020    07  01           킬 스위치                      Kill Switch
# 5  20200701  2020    07  01       인베이젼 2020                         Invasion
# 6  20200701  2020    07  01             소리꾼                       The Singer
# 8  20200701  2020    07  01       부산행:익스텐디드
# 9  20200709  2020    07  09   모탈: 레전드 오브 토르                           MORTAL
#
#   directorpeopleNm   movieCd peopleNm cast actors
# 1              최상훈  20201785
# 7         예고르 바라노프  20200774
# 0              박철웅  20191242
# ...

# %%
movieIDDF=movieIDDF.set_index("movieCd")
movieIDDF.head()
# Out:
#             openDt  year month day         movieNm  \
# movieCd
# 20201785                                       태백권
# 20200774                            블랙아웃 : 인베이젼 어스
# 20191242  20200423  2020    04  23          대전 블루스
# 20200083  20200701  2020    07  01         해피 디 데이
# 20200912  20200701  2020    07  01       포스 오브 네이쳐
#
#                                 movieNmEn directorpeopleNm peopleNm cast  \
# movieCd
# 20201785  The Therapist: Fist of Tae-baek              최상훈
# 20200774                         Avanpost         예고르 바라노프
# 20191242           Last Blues, Last Dance              박철웅
# 20200083                         Dog Days            켄 마리노
# 20200912                  Force of Nature          마이클 폴리쉬
#
#          actors
# movieCd
# 20201785
# 20200774
# 20191242
# 20200083
# 20200912

# %%
col_list = ["openDt", "year", "month", "day", "movieNm", "movieNmEn","directorpeopleNm","movieCd"]
movieIDDF = movieIDDF.loc[:, col_list]
movieIDDF.head(10)
# Out:
#      openDt  year month day         movieNm                        movieNmEn  \
# 1                                       태백권  The Therapist: Fist of Tae-baek
# 7                            블랙아웃 : 인베이젼 어스                         Avanpost
# 0  20200423  2020    04  23          대전 블루스           Last Blues, Last Dance
# 2  20200701  2020    07  01         해피 디 데이                         Dog Days
# 3  20200701  2020    07  01       포스 오브 네이쳐                  Force of Nature
# 4  20200701  2020    07  01           킬 스위치                      Kill Switch
# 5  20200701  2020    07  01       인베이젼 2020                         Invasion
# 6  20200701  2020    07  01             소리꾼                       The Singer
# 8  20200701  2020    07  01       부산행:익스텐디드
# 9  20200709  2020    07  09   모탈: 레전드 오브 토르                           MORTAL
#
#   directorpeopleNm   movieCd
# 1              최상훈  20201785
# 7         예고르 바라노프  20200774
# 0              박철웅  20191242
# 2            켄 마리노  20200083
# ...

# %%
movieIDDF.to_csv("kobis20200630.csv", encoding = "cp949")

# %%
tempURL = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079"
tempURL
# Out:
# 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=430156241533f1d058c603178cc3ca0e&movieCd=20124079'

# %%
tempDataPage = urllib.request.urlopen(tempURL)
tempData = json.loads(tempDataPage.read().decode('utf8'), encoding="utf8")
tempData
# Out:
# {'movieInfoResult': {'movieInfo': {'movieCd': '20124079',
#    'movieNm': '광해, 왕이 된 남자',
#    'movieNmEn': 'Masquerade',
#    'movieNmOg': '',
#    'showTm': '131',
#    'prdtYear': '2012',
#    'openDt': '20120913',
#    'prdtStatNm': '개봉',
#    'typeNm': '장편',
#    'nations': [{'nationNm': '한국'}],
#    'genres': [{'genreNm': '사극'}, {'genreNm': '드라마'}],
#    'directors': [{'peopleNm': '추창민', 'peopleNmEn': 'CHOO Chang-min'}],
#    'actors': [{'peopleNm': '이병헌',
#      'peopleNmEn': 'LEE Byung-hun',
#      'cast': '광해/하선',
#      'castEn': ''},
#     {'peopleNm': '류승룡',
#      'peopleNmEn': 'RYU Seung-ryong',
#      'cast': '허균',
#      'castEn': ''},
#     {'peopleNm': '한효주',
#      'peopleNmEn': 'HAN Hyo-joo',
#      'cast': '중전',
#      'castEn': ''},
#     {'peopleNm': '장광',
#      'peopleNmEn': 'JANG Kwang',
#      'cast': '조내관',
#      'castEn': ''},
#     {'peopleNm': '김인권',
#      'peopleNmEn': 'KIM In-kwon',
#      'cast': '도부장',
#      'castEn': ''},
# ...

# %%
tempData["movieInfoResult"]["movieInfo"]["movieNm"]
# Out:
# '광해, 왕이 된 남자'

# %%
tempData["movieInfoResult"]["movieInfo"]["typeNm"]
# Out:
# '장편'

# %%
tempData["movieInfoResult"]["movieInfo"]["actors"][0]["peopleNm"]
# Out:
# '이병헌'

# %%
tempData["movieInfoResult"]["movieInfo"]["actors"][0]["cast"]
# Out:
# '광해/하선'

# %%
len(tempData["movieInfoResult"]["movieInfo"]["actors"])
# Out:
# 35

# %%
#1 기존의 DF에 필요한 컬럼 추가 : 장르, 1번 배우 이름, 1번 배우 배역 이름, 출연배우숫자
DF["필요한 컬럼이름 추가"] = ""
....
#2) 내가 가지고 있는 DF의 가로줄이 몇 개인지 확인(len, shape 등..)-->
--->for 반복을 숫자로 하는 경우, 
#3)
for i in ~~~~~:
    1) i번째 영화에 대한 상세정보 요청 주소 만들기...
    2) i번째 영화에 대한 상세정보 주소를 http통신으로 요청하고 받아서 JSON패키지 활용해서 변환
    3) i번째 영화에 대해서 받은 상세정보를 가지고 필요한 정보 추출
        ---> 추출 후에 i번째 영화의 장르/배우이름/배역/

# %%
movieIDDF
# Out:
#             openDt  year month day         movieNm  \
# movieCd
# 20201785                                       태백권
# 20200774                            블랙아웃 : 인베이젼 어스
# 20191242  20200423  2020    04  23          대전 블루스
# 20200083  20200701  2020    07  01         해피 디 데이
# 20200912  20200701  2020    07  01       포스 오브 네이쳐
# 20200802  20200701  2020    07  01           킬 스위치
# 20208617  20200701  2020    07  01       인베이젼 2020
# 20196201  20200701  2020    07  01             소리꾼
# 20200846  20200701  2020    07  01       부산행:익스텐디드
# 20201385  20200709  2020    07  09   모탈: 레전드 오브 토르
#
#                                 movieNmEn directorpeopleNm peopleNm cast  \
# movieCd
# 20201785  The Therapist: Fist of Tae-baek              최상훈
# 20200774                         Avanpost         예고르 바라노프
# 20191242           Last Blues, Last Dance              박철웅
# 20200083                         Dog Days            켄 마리노
# 20200912                  Force of Nature          마이클 폴리쉬
# ...

# %%
fistURL = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=80b1793712960b5dfe1c3386942f37d9&movieCd=20201785"
fistURL
# Out:
# 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=80b1793712960b5dfe1c3386942f37d9&movieCd=20201785'

# %%
fistDataPage = urllib.request.urlopen(fistURL)
fistData = json.loads(fistDataPage.read().decode('utf8'), encoding="utf8")
fistData
# Out:
# {'movieInfoResult': {'movieInfo': {'movieCd': '20201785',
#    'movieNm': '태백권',
#    'movieNmEn': 'The Therapist: Fist of Tae-baek',
#    'movieNmOg': '',
#    'showTm': '107',
#    'prdtYear': '2020',
#    'openDt': '',
#    'prdtStatNm': '',
#    'typeNm': '장편',
#    'nations': [{'nationNm': '한국'}],
#    'genres': [{'genreNm': '코미디'}, {'genreNm': '가족'}, {'genreNm': '액션'}],
#    'directors': [{'peopleNm': '최상훈', 'peopleNmEn': 'CHOI Sang-hun'}],
#    'actors': [{'peopleNm': '오지호',
#      'peopleNmEn': 'OH Ji-ho',
#      'cast': '',
#      'castEn': ''},
#     {'peopleNm': '신소율',
#      'peopleNmEn': 'SHIN So-yul',
#      'cast': '',
#      'castEn': ''}],
#    'showTypes': [],
#    'companys': [],
#    'audits': [],
#    'staffs': []},
#   'source': '영화진흥위원회'}}

# %%
movieIDDF["typeNm"] = ""
movieIDDF["peopleNm"] = ""
movieIDDF["cast"] = ""
movieIDDF["actors"] = ""

dataLen = len(movieIDDF)
for i in range(0, dataLen):
    tempURL_part1 = """http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=80b1793712960b5dfe1c3386942f37d9"""
    #keyNum = """80b1793712960b5dfe1c3386942f37d9"""
    tempURL_part2 = """&movieCd="""
    movieId = str(movieIDDF.index[i])
    tempURL = tempURL_part1 + tempURL_part2 + movieId
    
    tempDataPage = urllib.request.urlopen(tempURL)
    tempData = json.loads(tempDataPage.read().decode('utf8'), encoding="utf8")

    
    
    #at 사용시
    
    movieIDDF.at[movieIDDF.index[i],"typeNm"]=tempData["movieInfoResult"]["movieInfo"]["typeNm"]
    
    if tempData["movieInfoResult"]["movieInfo"]["actors"]:
        movieIDDF.at[movieIDDF.index[i],"peopleNm"]=tempData["movieInfoResult"]["movieInfo"]["actors"][0]["peopleNm"]
    else:
        pass
    
    if tempData["movieInfoResult"]["movieInfo"]["actors"]:
        movieIDDF.at[movieIDDF.index[i],"cast"]=tempData["movieInfoResult"]["movieInfo"]["actors"][0]["cast"]
    else:
        pass
    
    if tempData["movieInfoResult"]["movieInfo"]["actors"]:
        movieIDDF.at[movieIDDF.index[i],"actors"]=len(tempData["movieInfoResult"]["movieInfo"]["actors"])
    else:
        pass
    
movieIDDF
# Out:
#             openDt  year month day         movieNm  \
# movieCd
# 20201785                                       태백권
# 20200774                            블랙아웃 : 인베이젼 어스
# 20191242  20200423  2020    04  23          대전 블루스
# 20200083  20200701  2020    07  01         해피 디 데이
# 20200912  20200701  2020    07  01       포스 오브 네이쳐
# 20200802  20200701  2020    07  01           킬 스위치
# 20208617  20200701  2020    07  01       인베이젼 2020
# 20196201  20200701  2020    07  01             소리꾼
# 20200846  20200701  2020    07  01       부산행:익스텐디드
# 20201385  20200709  2020    07  09   모탈: 레전드 오브 토르
#
#                                 movieNmEn directorpeopleNm    peopleNm cast  \
# movieCd
# 20201785  The Therapist: Fist of Tae-baek              최상훈         오지호
# 20200774                         Avanpost         예고르 바라노프    알렉세이 차도프
# 20191242           Last Blues, Last Dance              박철웅         반민정
# 20200083                         Dog Days            켄 마리노     바네사 허진스
# ...
