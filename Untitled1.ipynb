# %%
import pandas as pd
import numpy as np

# %%
covid19=pd.read_csv("C:\\Users\\acorn-519\\Downloads\\covid_19_\\PatientInfo.csv")
covid19.head()
# Out:
#    patient_id     sex  age country province city        infection_case  \
# 0  1000000001    male  50s   Korea       서울  강서구       overseas inflow
# 1  1000000002    male  30s   Korea       서울  중랑구       overseas inflow
# 2  1000000003    male  50s   Korea       서울  종로구  contact with patient
# 3  1000000004    male  20s   Korea       서울  마포구       overseas inflow
# 4  1000000005  female  20s   Korea       서울  성북구  contact with patient
#
#   infected_by contact_number symptom_onset_date confirmed_date released_date  \
# 0         NaN             75         2020-01-22     2020-01-23    2020-02-05
# 1         NaN             31                NaN     2020-01-30    2020-03-02
# 2  2002000001             17                NaN     2020-01-30    2020-02-19
# 3         NaN              9         2020-01-26     2020-01-30    2020-02-15
# 4  1000000002              2                NaN     2020-01-31    2020-02-24
#
#   deceased_date     state
# 0           NaN  released
# ...

# %%
covid19.sort_values(by="confirmed_date",ascending=False)
# Out:
#       patient_id     sex  age country province city        infection_case  \
# 1986  1400000343  female  NaN   Korea       인천  NaN       overseas inflow
# 3706  4100000168     NaN  20s   Korea     충청남도  부여군       overseas inflow
# 1985  1400000342  female  NaN   Korea       인천  NaN       overseas inflow
# 2104  1500000118  female  20s   Korea       대전   동구       overseas inflow
# 2106  1500000120    male  10s   Korea       대전   동구  contact with patient
# ...          ...     ...  ...     ...      ...  ...                   ...
# 0     1000000001    male  50s   Korea       서울  강서구       overseas inflow
# 1644  1400000001  female  30s   China       인천   기타       overseas inflow
# 4730  6011000051  female  40s   Korea     경상북도  안동시                   etc
# 4731  6011000052  female   0s   Korea     경상북도  안동시                   etc
# 4732  6011000053  female  10s   Korea     경상북도  안동시                   etc
#
#      infected_by contact_number symptom_onset_date confirmed_date  \
# ...
